# %% [markdown]
# # ex2_scientific1
# ## Nội dung bài học
# Hiển thị ngẫu nhiên $N=50$ hình tròn:
# + Tâm $c_i = (x_i,y_i)$ ngẫu nhiên với $x_i, y_i \in \left[0, 1 \right]$
# + Màu sắc $color_i$ ngẫu nhiên với $color_i \in \left[0, 1 \right]$
# + Diện tích $area_i = \pi * r_i^2$ với sinh ngẫu nhiên $r_i \in \left[0, 1 \right]$
# ## Bài làm

# %% [markdown]
# ## Import thư viên

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython import display # hiển thị rich output

# %% [markdown]
# ### Sinh ngẫu nhiên hình tròn

# %%
# %time
# generate randomly the center (x,y ) of circle, color, area
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = np.pi * (15 * np.random.rand(N)) ** 2  # 0 to 15 point radii
# Out:
# CPU times: total: 0 ns
# Wall time: 10.5 μs

# %%
# Mã kiểm tra dữ liệu
print(f'+ x: len={len(x):d}, [{min(x):.2f}, {max(x):.2f}]: 10 samples [{x[0:10]}]')
print(f'+ y: len={len(y):d}, [{min(y):.2f}, {max(y):.2f}]: 10 samples [{y[0:10]}]')
print(f'+ colors: len={len(colors):d}, [{min(colors):.2f}, {max(colors):.2f}]: 10 samples [{colors[0:10]}]')
print(f'+ area: len={len(area):d}, [{min(area):.2f}, {max(area):.2f}]: 10 samples [{area[0:10]}]')
# Out:
# + x: len=50, [0.01, 0.99]: 10 samples [[0.5114739  0.19097183 0.45981365 0.00602202 0.04593951 0.15086762
#  0.63210253 0.68662026 0.8042486  0.26274029]]
# + y: len=50, [0.10, 0.99]: 10 samples [[0.37046971 0.40029082 0.80276527 0.36657509 0.41333786 0.68514716
#  0.32834336 0.46407308 0.42866194 0.64254417]]
# + colors: len=50, [0.00, 0.99]: 10 samples [[0.05840055 0.91510691 0.26118673 0.14215101 0.16105115 0.59563261
#  0.33294194 0.23598658 0.89589326 0.4038305 ]]
# + area: len=50, [0.04, 682.36]: 10 samples [[300.22695353 144.34757525   1.76744054  20.12541283 299.74129534
#  255.42032879 190.41889746  62.82431932  66.52863636 417.38183981]]

# %% [markdown]
# ### Hiển thị đồ thị

# %%
# %matplotlib inline
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %% [markdown]
# # Kết thúc
